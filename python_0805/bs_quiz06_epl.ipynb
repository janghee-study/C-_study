# %% [markdown]
# ### 오늘의 프리미어리그 순위를 html로 나타내어라~

# %%
from bs4 import BeautifulSoup
import urllib.request

# %%
#HTML소스코드 가져오기
url = "https://sports.news.naver.com/wfootball/record/index.nhn?category=epl&tab=team"
res = urllib.request.urlopen(url)
data = res.read()
#디코딩하기
text = data.decode('utf-8')
soup = BeautifulSoup(text,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image">
# <meta content="네이버 스포츠" property="og:title">
# <meta content="스포츠의 시작과 끝!" property="og:description">
# <meta content="sports.news.naver.com/wfootball/record/index.nhn?category=epl&amp;league=100&amp;tab=team" property="og:url"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2020/07/31/174012/css/nsports.css" rel="stylesheet" type="text/css"/>
# <title>기록/순위, 해외축구 : 네이버 스포츠</title>
# <script charset="UTF-8" src="https://ssl.pstatic.net/static.sports/resources/pc/2020/07/31/174012/js/generated/record.js" type="text/javascript"></script>
# <script>
# 	try {
# 		var deployPhase = 'release';
# 		if (deployPhase === 'release') {
# 			JEagleEyeClient.attachOnError();
#
# 		} else if (deployPhase === 'dev') {
# 			JEagleEyeClient.setDebugOnly(true);
# 			JEagleEyeClient.attachOnError();
#
# 		} else {
# 			// local
# 			JEagleEyeClient.attachOnError();
# 		}
# 	} catch (e) {
# 		console.log(e);
# 	}
# </script>
# <script language="javascript" src="https://ssl.pstatic.net/static/common/js/cs_ops_webncc.js?2011092101" type="text/javascript"></script>
# <script type="text/javascript">
# document.domain = "naver.com";
# var sports_category='epl';
# var ccsrv="cc.naver.com";
# var nsc = "sports.worldfootball";
# function noImg (element) {
# 	element.src = "https://sports-phinf.pstatic.net/common/type_player_v2.png";
# 	$(element).attr("height") && $(element).removeAttr("height");
# 	$(element).next() && $(element).next().hide();
# }
# document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
# </script>
# </meta></meta></meta></head>
# <body>
# <div id="u_skip">
# <a href="#lnb_main_sub" onclick="document.getElementById('lnb_main_sub').tabIndex=-1;document.getElementById('lnb_main_sub').focus();"><span>메인 메뉴로 바로가기</span></a>
# <div id="lnb_menu_link"></div>
# <div id="container_link"></div>
# </div>
# <div id="wrap">
# <div class="header" id="header">
# <div class="sports_header" role="banner">
# <div class="snb_area">
# <h1 class="logo_group">
# <a class="logo_naver" href="https://www.naver.com" onclick="clickcr(this, 'STA.naverlogo', '', '', event);"><span class="blind">네이버</span></a>
# <a class="logo_sports" href="https://sports.news.naver.com/" onclick="clickcr(this, 'STA.sports', '', '', event);"><span class="blind">스포츠</span></a>
# </h1>
# <div class="service_group">
# <a class="link_news_service" href="https://news.naver.com/" onclick="clickcr(this, 'STA.news', '', '', event);"><span class="blind">뉴스</span></a>
# <a class="link_weather_service" href="https://weather.naver.com/" onclick="clickcr(this, 'STA.whether', '', '', event);"><span class="blind">날씨</span></a>
# <a class="link_entertain_service" href="https://entertain.naver.com/" onclick="clickcr(this, 'STA.entertain', '', '', event);"><span class="blind">TV연예</span></a>
# </div>
# </div>
# <!-- GNB -->
# <div class="gnb_area">
# <div class="gnb_one" id="gnb"></div>
# </div>
# <!-- GNB -->
# </div>
# <!-- 추후 제거, lnbMenuInfoList 를 받아오기 위하여 사용중 -->
# <script>
# 	var lnbMenuInfoList = [{"a":"","side":"left","c":"sportshome","subMenuList":[],"h":22,"alt":"스포츠홈","className":"","l":"0","upperSection":null,"url":"/index.nhn","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/home.png","alt_u":"","w":60,"onUrl":"","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/home_on.png"},{"a":"","side":"left","c":"baseball","subMenuList":[{"a":"0","side":"","c":"news","h":22,"alt":"최신뉴스","className":"","l":"0","upperSection":null,"url":"/kbaseball/news/index.nhn","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_news.png","alt_u":"","w":60,"onUrl":"/kbaseball/news/read.nhn;/kbo/news/read.nhn;/baseballetc/news/read.nhn;/kbaseball/news/index.nhn;/kbo/news/index.nhn;/baseballetc/news/index.nhn;/news.nhn","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_news_on.png"},{"a":"0","side":"","c":"video","h":22,"alt":"영상","className":"","l":"0","upperSection":null,"url":"/kbaseball/vod/index.nhn","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_video.png","alt_u":"","w":39,"onUrl":"","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_video_on.png"},{"a":"0","side":"","c":"album","h":22,"alt":"생생화보","className":"","l":"0","upperSection":null,"url":"/photocenter/albumList.nhn?category=kbo","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_photo.png","alt_u":"","w":60,"onUrl":"/photocenter/photoList.nhn?category=kbo;/photocenter/photo.nhn?category=kbo","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_photo_on.png"},{"a":"0","side":"","c":"schedule","h":22,"alt":"일정/결과","className":"","l":"0","upperSection":null,"url":"/kbaseball/schedule/index.nhn","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_schedule.png","alt_u":"","w":65,"onUrl":"/gameCenter/gameResult.nhn?category=kbo;/gameCenter/textRelay.nhn?category=kbo;/gameCenter/gameRecord.nhn?category=kbo;/gameCenter/gameVideo.nhn?category=kbo","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_schedule_on.png"},{"a":"0","side":"","c":"datacenter","h":22,"alt":"기록/순위","className":"","l":"0","upperSection":null,"url":"/kbaseball/record/index.nhn?category=kbo","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_record.png","alt_u":"","w":66,"onUrl":"/kbaseball/record/index.nhn?category=kbo","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_record_on.png"},{"a":"0","side":"","c":"issue","h":22,"alt":"구단/협회","className":"","l":"0","upperSection":null,"url":"/kbaseball/column/columnistList.nhn","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_column.png","alt_u":"","w":64,"onUrl":"/kbaseball/column/columnList.nhn;/kbaseball/news/read.nhn?viewType=CLUB","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_column_on.png"},{"a":"0","side":"","c":"baseball9","h":22,"alt":"야구9단","className":"","l":"0","upperSection":null,"url":"http://ya9.naver.com/?adtr=A19A126","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_ya9.png","alt_u":"","w":58,"onUrl":"","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_ya9.png"}],"h":22,"alt":"야구","className":"","l":"0","upperSection":"kbaseball","url":"/kbaseball/index.nhn","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/baseball.png","alt_u":"","w":38,"onUrl":"/sports/index.nhn?category=baseball;/kbaseball/index.nhn;/kbaseball/issue/index.nhn;","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/baseball_on.png"},{"a":"","side":"left","c":"worldbaseball","subMenuList":[{"a":"0","side":"","c":"news","h":22,"alt":"최신뉴스","className":"","l":"0","upperSection":null,"url":"/wbaseball/news/index.nhn","off":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_news.png","alt_u":"","w":60,"onUrl":"/wbaseball/news/read.nhn;/mlb/news/index.nhn;/npb/news/index.nhn;/mlb/news/read.nhn;/npb/news/read.nhn;/news.nhn","on":"https://imgsports.pstatic.net/images/2015/PC/lnb2/sub_news_on.png"},{"a":"0","side":"","c":"video","h":22,"alt":"영상","className":"","l":"0","upperSection":null,"url":"/wbase ...
# </script>
# <div class="sports_menu" id="_sports_lnb_menu" role="navigation">
# <div class="menu_area">
# <h2 class="blind">메인 메뉴</h2>
# <ul class="main_menu_list" role="menubar">
# </ul>
# <ul class="side_menu_list" role="menubar">
# </ul>
# <form action="https://search.naver.com/search.naver" method="get" name="news_search" target="_blank">
# <fieldset class="search_field">
# <legend class="blind">스포츠 검색</legend>
# <input name="where" type="hidden" value="news"/>
# <input name="ie" type="hidden" value="UTF-8"/>
# <input aria-label="검색어 입력" class="input_search" id="query" name="query" type="text"/>
# <button class="button_search" id="querybtn" onclick="javascript:clickcr(this, 'LNB.search', '', '', event);" type="submit"><span class="blind">검색</span>
# </button>
# </fieldset>
# </form>
# </div>
# </div>
# <script id="_sports_lnb_menu_li_template" type="text/x-handlebars-template">
# 	<li class="main_menu_item" role="presentation">
# 		<a href="{{url}}" class="link_main_menu" role="menuitem" {{#if selected}}aria-current="page" {{/if}}
# 																									   onclick="clickcr(this,
# 																									   'LNB.{{c}}',
# 																									   '{{c}}', '',
# 																									   event);">{{alt}}</a>
# 		<ul class="sub_menu_list" role="menubar">
# 			{{#each subMenuList}}
# 			<li class="sub_menu_item {{#isSpotType}}type_spot{{/isSpotType}}" role="presentation">
# 				<a href="{{url}}" class="link_sub_menu" role="menuitem"
# 				   onclick="clickcr(this, 'LNB.{{c}}', '{{c}}', '', event);" {{#if selected}}aria-current="page" {{/if}}>{{alt}}</a>
# 			</li>
# 			{{/each}}
# 		</ul>
# 	</li>
# </script>
# <script>
# 	naver = window.naver || {};
# 	naver.sports = naver.sports || {};
# 	naver.sports.top = naver.sports.top || {};
# 	naver.sports.top.Lnb = eg.Class({
#
# 		construct: function (htOption) {
# 			this._initVars(htOption);
# 			this._initHandlebarsTemplate();
# 			this._init();
# 			this._setEventHandler();
# 		},
# 		_initVars: function (htOption) {
# 			this._lnbMenus = htOption.lnbMenus || {};
# 			this._pathname = location.pathname;
# 			this._search = location.search;
# 			this._targetUpperSection = htOption.targetUpperSection;
#
# 		},
# 		_initHandlebarsTemplate: function () {
# 			this._sportsLnbMenuLiTemplate = Handlebars.compile($("#_sports_lnb_menu_li_template").html());
#
#
# 			Handlebars.registerHelper('isSpotType', function (options) {
# 				if (this.c === 'baseball9' || this.c === 'spotv') {
# 					return options.fn(this);
# 				} else {
# 					return options.inverse(this);
# 				}
# 			});
#
# 		},
# 		_init: function () {
#
# 			if ($("div#lnb_main_sub").length > 0) {
# 				$("div#lnb_main_sub").detach();
# 			}
#
# 			_.each(this._lnbMenus, $.proxy(function (menu) {
# 				var upperSection = menu.upperSection;
# 				this._updateSelectedMenu(menu, upperSection);
# 				_.each(menu.subMenuList, $.proxy(function (subMenu) {
# 					this._updateSelectedMenu(subMenu, upperSection);
# 				}, this));
# 			}, this));
#
# 			this._draw();
# 		},
# 		_setEventHandler: function () {
# 		},
# 		_draw: function () {
# 			_.each(this._lnbMenus, $.proxy(function (menu) {
# 				var menuHtml = this._sportsLnbMenuLiTemplate(menu);
#
# 				if (menu.side === 'left') {
# 					$("#_sports_lnb_menu ul.main_menu_list").last().append(menuHtml);
# 				} else {
# 					$("#_sports_lnb_menu ul.side_menu_list").last().append(menuHtml);
# 				}
#
# 			}, this));
#
# 			if ($("a.link_main_menu[aria-current='page']").siblings("ul").children().length > 0) {
# 				$("#_sports_lnb_menu").addClass("type_submenu");
# 			}
# 		},
#
# 		_updateSelectedMenu: function (menu, upperSection) {
# 			var urlListToActivate = this._getUrlListToActivate(menu);
# 			for (var j = 0; j < urlListToActivate.length; j++) {
# 				var urlToActivate = urlListToActivate[j];
#
#
# 				if (_.isEqual(urlToActivate, this._pathname) && _.isEqual(this._pathname, "/news.nhn") && _.isEqual(upperSection, this._targetUpperSection)) {
# 					menu.selected = true;
# 				} else if (_.isEqual(urlToActivate, this._pathname) && !_.isEqual(this._pathname, "/news.nhn")) {
# 					menu.selected = true;
# 				} else if (urlToActivate.indexOf(this._pathname) > -1 && this._hasQueryParameterToActivate(urlToActivate, this._search)) {
# 					menu.selected = true;
# 				}
# 			}
# 		},
#
# 		_getUrlListToActivate: function (lnbMenuInfo) {
# 			var result = [];
#
# 			result.push(lnbMenuInfo.url);
#
# 			var urlListToActivate = [];
# 			var onUrl = $.trim(lnbMenuInfo.onUrl);
#
# 			if (onUrl.length > 0) {
# 				urlListToActivate = onUrl.split(";");
# 				result = result.concat(urlListToActivate);
# 			}
#
# 			var subMenuList = lnbMenuInfo.subMenuList;
#
# 			if (subMenuList) {
# 				for (var i = 0; i < subMenuList.length; i++) {
# 					var subMenu = lnbMenuInfo.subMenuList[i];
# 					result.push(subMenu.url);
# 					var onSubUrl = $.trim(subMenu.onUrl);
# 					if (onUrl.length > 0) {
# 						result = result.concat(onSubUrl.split(";"));
# 					}
# 				}
# 			}
#
# 			return result;
# 		},
# 		_hasQueryParameterToActivate: function (urlToActivate, currentQueryParameter) {
# 			var queryParameterToActivate = getURLParameter(urlToActivate);
# 			var currentQueryParameter = getURLParameter(currentQueryParameter);
#
# 			if (!queryParameterToActivate || !currentQueryParameter) {
# 				return;
# 			}
#
# 			var queryParameterToActivateMap = changeQueryStringToObject(queryParameterToActivate);
# 			var currentQueryParameterMap = changeQueryStringToObject(currentQueryParameter);
#
# 			for (var i in queryParameterToActivateMap) {
# 				for (var j in currentQueryParameterMap) {
# 					if (i == j && queryParameterToActivateMap[i] == currentQueryParameterMap[j]) {
# 						return true;
# 					}
# 				}
# 			}
#
# 			return false;
# 		}
# 	});
#
# 	new naver.sports.top.Lnb({
# 		"lnbMenus": lnbMenuInfoList,
# 		'targetUpperSection': ''
# 	});
# </script>
# </div>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20200806" type="text/javascript"></script>
# <script type="text/javascript">
# 	//NOTE : GNB init
# 	var gnb_option = {
# 		gnb_one_naver: 1,
# 		gnb_brightness: 1,
# 		gnb_login: encodeURIComponent(window.location.href),
# 		gnb_logout: encodeURIComponent(window.location.href)
# 	};
#
# 	(function () {
# 		function loadGNB() {
# 			//NOTE : https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn 회원쪽 gnb src 을 못 가져 왔을 때 방어처리
# 			if (typeof getGNB === "function") {
# 				getGNB();
# 			}
# 		}
#
# 		window.attachEvent ? window.attachEvent('onload', loadGNB) : window.addEventListener('load', loadGNB, false);
# 	})();
# </script>
# <div id="container">
# <div id="content">
# <div class="tab_event">
# <ul class="list">
# <li class="selected">
# <a href="/wfootball/record/index.nhn?category=epl&amp;league=100&amp;tab=team">
# <span class="menu">팀 순위<span class="blind">선택됨</span></span>
# </a>
# </li>
# <li>
# <a href="/wfootball/record/index.nhn?category=epl&amp;league=100&amp;tab=player">
# <span class="menu">개인 순위</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="record_tab">
# <ul class="list">
# <li class="selected">
# <a href="/wfootball/record/index.nhn?category=epl&amp;tab=team">
# <span class="menu">
# <img alt="프리미어리그" height="23" src="https://imgsports.pstatic.net/images/2020/pc/common/league/epl_on.png"/>
# <span class="title">프리미어리그</span>
# <span class="blind">선택됨</span>
# </span>
# </a>
# </li>
# <li>
# <a href="/wfootball/record/index.nhn?category=primera&amp;tab=team">
# <span class="menu">
# <img alt="라리가" height="23" src="https://imgsports.pstatic.net/images/2020/pc/common/league/primera.png"/>
# <span class="title">라리가</span>
# </span>
# </a>
# </li>
# <li>
# <a href="/wfootball/record/index.nhn?category=bundesliga&amp;tab=team">
# <span class="menu">
# <img alt="분데스리가" height="23" src="https://imgsports.pstatic.net/images/2020/pc/common/league/bundesliga.png"/>
# <span class="title">분데스리가</span>
# </span>
# </a>
# </li>
# <li>
# <a href="/wfootball/record/index.nhn?category=seria&amp;tab=team">
# <span class="menu">
# <img alt="세리에 A" height="23" src="https://imgsports.pstatic.net/images/2020/pc/common/league/seria.png"/>
# <span class="title">세리에 A</span>
# </span>
# </a>
# </li>
# <li>
# <a href="/wfootball/record/index.nhn?category=ligue1&amp;tab=team">
# <span class="menu">
# <img alt="리그 1" height="23" src="https://imgsports.pstatic.net/images/2020/pc/common/league/ligue1.png"/>
# <span class="title">리그 1</span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="record_sub_title with_combo_box">
# <h4 class="record_h"><span>2019/20 시즌</span> 팀 순위</h4>
# </div>
# <div class="date_select_nav type_season">
# <span class="blind">종목별 경기 날짜 및 시즌 선택</span>
# <!-- [D] 날짜 및 시즌 선택 컴포넌트 인 경우 div.select_box_area 에 .type_date 클래스를 추가 해 주세요. -->
# <div class="select_box_area type_date">
# <div class="select_box">
# <!-- [D]
# 				ul.option_list 가 닫혀있다면 aria-expanded="false"
# 				ul.option_list 가 열려있다면 aria-expanded="true" 로 적용 해 주세요.
# 			 -->
# <button aria-expanded="false" aria-haspopup="listbox" aria-label="시즌 선택" class="btn_toggle" id="_currentYearButton" onclick="toggleYearList();" type="button">
# <em class="now_selected"><span class="blind">선택된 시즌</span>2019<span class="dash">-</span>20</em>
# </button>
# <!-- [D] ul.option_list 가 열릴 때 .on 클래스를 추가 해 주세요. -->
# <ul class="option_list" id="_yearList" role="listbox">
# <!-- [D] 선텍된 button.btn_option 에 aria-selected="true" 를 적용 해 주세요. -->
# <!-- [D] 비활성화 되어야 하는 button.btn_option 에 disabled 속성을 추가 해 주세요. -->
# <li class="list" role="presentation">
# <button aria-selected="true" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2019&amp;tab=team'" role="option" type="button">2019-20</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2018&amp;tab=team'" role="option" type="button">2018-19</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2017&amp;tab=team'" role="option" type="button">2017-18</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2016&amp;tab=team'" role="option" type="button">2016-17</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2015&amp;tab=team'" role="option" type="button">2015-16</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2014&amp;tab=team'" role="option" type="button">2014-15</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2013&amp;tab=team'" role="option" type="button">2013-14</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2012&amp;tab=team'" role="option" type="button">2012-13</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2011&amp;tab=team'" role="option" type="button">2011-12</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2010&amp;tab=team'" role="option" type="button">2010-11</button>
# </li>
# <li class="list" role="presentation">
# <button aria-selected="false" class="btn_option" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2009&amp;tab=team'" role="option" type="button">2009-10</button>
# </li>
# </ul>
# </div>
# <!-- [D] 비활성화 되어야 하는 button.btn_move_date 에 disabled 속성을 추가 해 주세요. -->
# <button class="btn_move_date prev" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2018&amp;tab=team'" type="button"><span class="blind">이전 시즌으로 이동</span></button>
# <button class="btn_move_date next" disabled="" type="button"><span class="blind">다음 시즌으로 이동</span></button>
# </div>
# <div class="now_date_area">
# <button class="btn_now_date" onclick="location.href='/wfootball/record/index.nhn?category=epl&amp;year=2019'" type="button">현재<span class="blind">시즌으로 이동</span></button>
# </div>
# </div>
# <div class="record_tbl" id="wfootballTeamRecordBody">
# </div>
# <div class="state_desc">
# <ul>
# <li class="state1">챔피언스 리그 직행</li>
# <li class="state2">챔피언스 리그 예선</li>
# <li class="state3">유로파 리그</li>
# <li class="state4">강등 직행</li>
# </ul>
# </div>
# <script id="wfootballTeamRecordTemplate" type="text/x-handlebars-template">
#     <table summary="팀 순위" cellspacing="0">
#     <caption>팀 순위</caption>
#     <colgroup>
#         <col width="45">
#         <col width="*">
#         <col width="80">
#         <col width="80">
#         <col width="80">
#         <col width="80">
#         <col width="80">
#         <col width="80">
#         <col width="80">
#         <col width="80">
#     </colgroup>
#     <thead>
#     <tr>
#         <th scope="col">
#             <div class="inner">
#                 <strong>순위</strong>
#             </div>
#         </th>
#         <th scope="col" class="align_l">
#             <div class="inner">
#                 <strong>팀</strong>
#             </div>
#         </th>
#         <th scope="col">
#             <div class="inner">
#                 <strong>경기수</strong>
#             </div>
#         </th>
#         <!-- [D] 선택된 카테고리 활성화 강조 테두리 selected 클래스 추가 -->
#         <th scope="col" {{#ifeq teamRankOrder 'gainPoint'}}class="selected"{{/ifeq}}>
#             <a href="javascript:wfootballTeamRecordSortByColumn('gainPoint');" class="inner">
#                 <strong class="sort">승점</strong>
#             </a>
#         </th>
#         <th scope="col" {{#ifeq teamRankOrder 'won'}}class="selected"{{/ifeq}}>
#             <a href="javascript:wfootballTeamRecordSortByColumn('won', 'lost', 'manyFew');" class="inner">
#                 <strong class="sort">승</strong>
#             </a>
#         </th>
#         <th scope="col" {{#ifeq teamRankOrder 'drawn'}}class="selected"{{/ifeq}}>
#             <a href="javascript:wfootballTeamRecordSortByColumn('drawn', 'lost', 'manyFew');" class="inner">
#                 <strong class="sort">무</strong>
#             </a>
#         </th>
#         <th scope="col" {{#ifeq teamRankOrder 'lost'}}class="selected"{{/ifeq}}>
#             <a href="javascript:wfootballTeamRecordSortByColumn('lost', 'won', 'manyFew');" class="inner">
#                 <strong class="sort">패</strong>
#             </a>
#         </th>
#         <th scope="col" {{#ifeq teamRankOrder 'gainGoal'}}class="selected"{{/ifeq}}>
#             <a href="javascript:wfootballTeamRecordSortByColumn('gainGoal', 'loseGoal', 'manyFew');" class="inner">
#                 <strong class="sort">득점</strong>
#             </a>
#         </th>
#         <th scope="col" {{#ifeq teamRankOrder 'loseGoal'}}class="selected"{{/ifeq}}>
#             <a href="javascript:wfootballTeamRecordSortByColumn('loseGoal', 'gainGoal', 'manyFew');" class="inner">
#                 <strong class="sort">실점</strong>
#             </a>
#         </th>
#         <th scope="col" {{#ifeq teamRankOrder 'goalGap'}}class="selected"{{/ifeq}}>
#             <a href="javascript:wfootballTeamRecordSortByColumn('goalGap', 'gainGoal', 'manyMany');" class="inner">
#                 <strong class="sort">득실차</strong>
#             </a>
#         </th>
#     </tr>
#     </thead>
#     <tbody>
#     {{#each regularTeamRecordList}}
#     <tr {{#if @last}}class="last"{{/if}}>
#         <!-- [D] 상위랭크는 best 클래스 추가 -->
#         <td class="num {{#ifeq @index 0}}best{{/ifeq}}">
#             <div class="inner {{#ifeq ../teamRankOrder 'gainPoint'}}{{teamRankingGroup}}{{/ifeq}}">
#                 <strong>{{rank}}</strong>
#
#                     {{#ifeq teamRankingGroup 'champsLeague'}}
#                     <span class="state_bar1"><span class="blind">챔피언스 리그 직행</span></span>
#                     {{/ifeq}}
#                     {{#ifeq teamRankingGroup 'chamsLeagueQualifiers'}}
#                     <span class="state_bar2"><span class="blind">챔피언스 리그 예선</span></span>
#                     {{/ifeq}}
#                     {{#ifeq teamRankingGroup 'europaLeague'}}
#                     <span class="state_bar3"><span class="blind">유로파 리그</span></span>
#                     {{/ifeq}}
#                     {{#ifeq teamRankingGroup 'relegation'}}
#                     <span class="state_bar4"><span class="blind">강등 직행</span></span>
#                     {{/ifeq}}
#
#             </div>
#         </td>
#         <td class="align_l">
#             <div class="inner">
#                 <img width="25" height="25" alt="" src="https://dthumb-phinf.pstatic.net/?src=https://sports-phinf.pstatic.net/team/wfootball/default/{{teamCode}}.png&type=f25_25&refresh=1" onError="javascript:src='https://sports-phinf.pstatic.net/team/no_emblem_s_square.png'" class="emblem">
#                 <span class="name">{{teamName}}</span>
#             </div>
#         </td>
#         <td>
#             <div class="inner">
#                 <span>{{gameCount}}</span>
#             </div>
#         </td>
#         <!-- [D] 선택된 카테고리 활성화 강조 테두리 selected 클래스 추가 -->
#         <td {{#ifeq ../teamRankOrder "gainPoint"}}class="selected"{{/ifeq}}>
#             <div class="inner">
#                 <span>{{gainPoint}}</span>
#             </div>
#         </td>
#         <td {{#ifeq ../teamRankOrder "won"}}class="selected"{{/ifeq}}>
#             <div class="inner">
#                 <span>{{won}}</span>
#             </div>
#         </td>
#         <td {{#ifeq ../teamRankOrder "drawn"}}class="selected"{{/ifeq}}>
#             <div class="inner">
#                 <span>{{drawn}}</span>
#             </div>
#         </td>
#         <td {{#ifeq ../teamRankOrder "lost"}}class="selected"{{/ifeq}}>
#             <div class="inner">
#                 <span>{{lost}}</span>
#             </div>
#         </td>
#         <td {{#ifeq ../teamRankOrder "gainGoal"}}class="selected"{{/ifeq}}>
#             <div class="inner">
#                 <span>{{gainGoal}}</span>
#             </div>
#         </td>
#         <td {{#ifeq ../teamRankOrder "loseGoal"}}class="selected"{{/ifeq}}>
#             <div class="inner">
#                 <span>{{loseGoal}}</span>
#             </div>
#         </td>
#         <td {{#ifeq ../teamRankOrder "goalGap"}}class="selected"{{/ifeq}}>
#             <div class="inner">
#                 <span>{{goalGap}}</span>
#             </div>
#         </td>
#     </tr>
#     {{/each}}
#     </tbody>
#     </table>
# </script>
# <script type="text/javascript">
#     var wfootballTeamRecord = new naver.sports.record.TeamRecord({
#         jsonTeamRecord: {"regularTeamRecordList":[{"teamName":"리버풀 FC","gainGoal":85,"gameCount":38,"lastResult":"3승 1무 1패","league":100,"gainPoint":99,"teamCode":"9","loseGoal":33,"foul":330,"lost":3,"won":32,"goalGap":52,"teamRankingGroup":"champsLeague","rank":1,"assist":null,"drawn":3},{"teamName":"맨체스터 시티 FC","gainGoal":102,"gameCount":38,"lastResult":"5승 0무 0패","league":100,"gainPoint":81,"teamCode":"11","loseGoal":35,"foul":361,"lost":9,"won":26,"goalGap":67,"teamRankingGroup":"champsLeague","rank":2,"assist":null,"drawn":3},{"teamName":"맨체스터 유나이티드 FC","gainGoal":66,"gameCount":38,"lastResult":"3승 2무 0패","league":100,"gainPoint":66,"teamCode":"12","loseGoal":36,"foul":423,"lost":8,"won":18,"goalGap":30,"teamRankingGroup":"champsLeague","rank":3,"assist":null,"drawn":12},{"teamName":"첼시 FC","gainGoal":69,"gameCount":38,"lastResult":"3승 0무 2패","league":100,"gainPoint":66,"teamCode":"4","loseGoal":54,"foul":386,"lost":12,"won":20,"goalGap":15,"teamRankingGroup":"champsLeague","rank":4,"assist":null,"drawn":6},{"teamName":"레스터 시티 FC","gainGoal":67,"gameCount":38,"lastResult":"1승 1무 3패","league":100,"gainPoint":62,"teamCode":"29","loseGoal":41,"foul":418,"lost":12,"won":18,"goalGap":26,"teamRankingGroup":"europaLeague","rank":5,"assist":null,"drawn":8},{"teamName":"토트넘 홋스퍼 FC","gainGoal":61,"gameCount":38,"lastResult":"3승 2무 0패","league":100,"gainPoint":59,"teamCode":"19","loseGoal":47,"foul":423,"lost":11,"won":16,"goalGap":14,"teamRankingGroup":"europaLeague","rank":6,"assist":null,"drawn":11},{"teamName":"울버햄튼 원더러스 FC","gainGoal":51,"gameCount":38,"lastResult":"2승 1무 2패","league":100,"gainPoint":59,"teamCode":"44","loseGoal":40,"foul":406,"lost":9,"won":15,"goalGap":11,"teamRankingGroup":"normal","rank":7,"assist":null,"drawn":14},{"teamName":"아스널 FC","gainGoal":56,"gameCount":38,"lastResult":"2승 1무 2패","league":100,"gainPoint":56,"teamCode":"1006","loseGoal":48,"foul":420,"lost":10,"won":14,"goalGap":8,"teamRankingGroup":"normal","rank":8,"assist":null,"drawn":14},{"teamName":"셰필드 유나이티드 FC","gainGoal":39,"gameCount":38,"lastResult":"2승 0무 3패","league":100,"gainPoint":54,"teamCode":"37","loseGoal":39,"foul":409,"lost":12,"won":14,"goalGap":0,"teamRankingGroup":"normal","rank":9,"assist":null,"drawn":12},{"teamName":"번리 FC","gainGoal":43,"gameCount":38,"lastResult":"2승 2무 1패","league":100,"gainPoint":54,"teamCode":"70","loseGoal":50,"foul":413,"lost":14,"won":15,"goalGap":-7,"teamRankingGroup":"normal","rank":10,"assist":null,"drawn":9},{"teamName":"사우샘프턴 FC","gainGoal":51,"gameCount":38,"lastResult":"2승 3무 0패","league":100,"gainPoint":52,"teamCode":"18","loseGoal":60,"foul":450,"lost":16,"won":15,"goalGap":-9,"teamRankingGroup":"normal","rank":11,"assist":null,"drawn":7},{"teamName":"에버턴 FC","gainGoal":44,"gameCount":38,"lastResult":"1승 2무 2패","league":100,"gainPoint":49,"teamCode":"8","loseGoal":56,"foul":472,"lost":15,"won":13,"goalGap":-12,"teamRankingGroup":"normal","rank":12,"assist":null,"drawn":10},{"teamName":"뉴캐슬 유나이티드 FC","gainGoal":38,"gameCount":38,"lastResult":"0승 1무 4패","league":100,"gainPoint":44,"teamCode":"31","loseGoal":58,"foul":370,"lost":16,"won":11,"goalGap":-20,"teamRankingGroup":"normal","rank":13,"assist":null,"drawn":11},{"teamName":"크리스탈 팰리스 FC","gainGoal":31,"gameCount":38,"lastResult":"0승 1무 4패","league":100,"gainPoint":43,"teamCode":"5","loseGoal":50,"foul":424,"lost":17,"won":11,"goalGap":-19,"teamRankingGroup":"normal","rank":14,"assist":null,"drawn":10},{"teamName":"브라이튼 앤 호브 알비온 FC","gainGoal":39,"gameCount":38,"lastResult":"1승 2무 2패","league":100,"gainPoint":41,"teamCode":"6795","loseGoal":54,"foul":385,"lost":15,"won":9,"goalGap":-15,"teamRankingGroup":"normal","rank":15,"assist":null,"drawn":14},{"teamName":"웨스트햄 유나이티드 FC","gainGoal":49,"gameCount":38,"lastResult":"2승 2무 1패","league":100,"gainPoint":39,"teamCode":"43","loseGoal":62,"foul":386,"lost":19,"won":10,"goalGap":-13,"teamRankingGroup":"normal","rank":16,"assist":null,"drawn":9},{"teamName":"아스톤 빌라 FC","gainGoal":41,"gameCount" ...
#         sortedTeamRecord: {"regularTeamRecordList":[{"teamName":"리버풀 FC","gainGoal":85,"gameCount":38,"lastResult":"3승 1무 1패","league":100,"gainPoint":99,"teamCode":"9","loseGoal":33,"foul":330,"lost":3,"won":32,"goalGap":52,"teamRankingGroup":"champsLeague","rank":1,"assist":null,"drawn":3},{"teamName":"맨체스터 시티 FC","gainGoal":102,"gameCount":38,"lastResult":"5승 0무 0패","league":100,"gainPoint":81,"teamCode":"11","loseGoal":35,"foul":361,"lost":9,"won":26,"goalGap":67,"teamRankingGroup":"champsLeague","rank":2,"assist":null,"drawn":3},{"teamName":"맨체스터 유나이티드 FC","gainGoal":66,"gameCount":38,"lastResult":"3승 2무 0패","league":100,"gainPoint":66,"teamCode":"12","loseGoal":36,"foul":423,"lost":8,"won":18,"goalGap":30,"teamRankingGroup":"champsLeague","rank":3,"assist":null,"drawn":12},{"teamName":"첼시 FC","gainGoal":69,"gameCount":38,"lastResult":"3승 0무 2패","league":100,"gainPoint":66,"teamCode":"4","loseGoal":54,"foul":386,"lost":12,"won":20,"goalGap":15,"teamRankingGroup":"champsLeague","rank":4,"assist":null,"drawn":6},{"teamName":"레스터 시티 FC","gainGoal":67,"gameCount":38,"lastResult":"1승 1무 3패","league":100,"gainPoint":62,"teamCode":"29","loseGoal":41,"foul":418,"lost":12,"won":18,"goalGap":26,"teamRankingGroup":"europaLeague","rank":5,"assist":null,"drawn":8},{"teamName":"토트넘 홋스퍼 FC","gainGoal":61,"gameCount":38,"lastResult":"3승 2무 0패","league":100,"gainPoint":59,"teamCode":"19","loseGoal":47,"foul":423,"lost":11,"won":16,"goalGap":14,"teamRankingGroup":"europaLeague","rank":6,"assist":null,"drawn":11},{"teamName":"울버햄튼 원더러스 FC","gainGoal":51,"gameCount":38,"lastResult":"2승 1무 2패","league":100,"gainPoint":59,"teamCode":"44","loseGoal":40,"foul":406,"lost":9,"won":15,"goalGap":11,"teamRankingGroup":"normal","rank":7,"assist":null,"drawn":14},{"teamName":"아스널 FC","gainGoal":56,"gameCount":38,"lastResult":"2승 1무 2패","league":100,"gainPoint":56,"teamCode":"1006","loseGoal":48,"foul":420,"lost":10,"won":14,"goalGap":8,"teamRankingGroup":"normal","rank":8,"assist":null,"drawn":14},{"teamName":"셰필드 유나이티드 FC","gainGoal":39,"gameCount":38,"lastResult":"2승 0무 3패","league":100,"gainPoint":54,"teamCode":"37","loseGoal":39,"foul":409,"lost":12,"won":14,"goalGap":0,"teamRankingGroup":"normal","rank":9,"assist":null,"drawn":12},{"teamName":"번리 FC","gainGoal":43,"gameCount":38,"lastResult":"2승 2무 1패","league":100,"gainPoint":54,"teamCode":"70","loseGoal":50,"foul":413,"lost":14,"won":15,"goalGap":-7,"teamRankingGroup":"normal","rank":10,"assist":null,"drawn":9},{"teamName":"사우샘프턴 FC","gainGoal":51,"gameCount":38,"lastResult":"2승 3무 0패","league":100,"gainPoint":52,"teamCode":"18","loseGoal":60,"foul":450,"lost":16,"won":15,"goalGap":-9,"teamRankingGroup":"normal","rank":11,"assist":null,"drawn":7},{"teamName":"에버턴 FC","gainGoal":44,"gameCount":38,"lastResult":"1승 2무 2패","league":100,"gainPoint":49,"teamCode":"8","loseGoal":56,"foul":472,"lost":15,"won":13,"goalGap":-12,"teamRankingGroup":"normal","rank":12,"assist":null,"drawn":10},{"teamName":"뉴캐슬 유나이티드 FC","gainGoal":38,"gameCount":38,"lastResult":"0승 1무 4패","league":100,"gainPoint":44,"teamCode":"31","loseGoal":58,"foul":370,"lost":16,"won":11,"goalGap":-20,"teamRankingGroup":"normal","rank":13,"assist":null,"drawn":11},{"teamName":"크리스탈 팰리스 FC","gainGoal":31,"gameCount":38,"lastResult":"0승 1무 4패","league":100,"gainPoint":43,"teamCode":"5","loseGoal":50,"foul":424,"lost":17,"won":11,"goalGap":-19,"teamRankingGroup":"normal","rank":14,"assist":null,"drawn":10},{"teamName":"브라이튼 앤 호브 알비온 FC","gainGoal":39,"gameCount":38,"lastResult":"1승 2무 2패","league":100,"gainPoint":41,"teamCode":"6795","loseGoal":54,"foul":385,"lost":15,"won":9,"goalGap":-15,"teamRankingGroup":"normal","rank":15,"assist":null,"drawn":14},{"teamName":"웨스트햄 유나이티드 FC","gainGoal":49,"gameCount":38,"lastResult":"2승 2무 1패","league":100,"gainPoint":39,"teamCode":"43","loseGoal":62,"foul":386,"lost":19,"won":10,"goalGap":-13,"teamRankingGroup":"normal","rank":16,"assist":null,"drawn":9},{"teamName":"아스톤 빌라 FC","gainGoal":41,"gameCoun ...
#         teamRecordBodyName: "wfootballTeamRecordBody",
#         teamRecordTemplateName: "wfootballTeamRecordTemplate",
#         initTeamRankOrder: "gainPoint"
#     });
#
#     function wfootballTeamRecordSortByColumn(firstColumnName, secondColumnName, comparatorType) {
#         wfootballTeamRecord.teamRecordSortByColumn(firstColumnName, secondColumnName, comparatorType);
#     }
#
# 	function toggleYearList() {
# 		$("#_yearList").toggleClass("on");
# 		$("#_currentYearButton").attr("aria-expanded", $("#_yearList").hasClass("on"));
# 	}
#
# 	function toggleMonthList() {
# 		$("#_monthList").toggleClass("on");
# 		$("#_currentMonthButton").attr("aria-expanded", $("#_monthList").hasClass("on"));
# 	}
#
# </script>
# <!-- 기록 가이드 -->
# <div class="record_info">
# <!-- [D] 블릿('※') 스타일의 안내문구 리스트는 아래와 같이 p_noti 내 일괄 적용해주세요. -->
# <ul class="p_noti">
# <li>※ 해외축구 순위는 다음 시즌 경기 일정이 제공된 이후부터 승격, 강등 정보가 반영된 새 시즌 순위표로 노출됩니다.</li>
# </ul>
# <p class="p_desc">
#         네이버 스포츠에서 제공하는 일정, 결과, 기록 등의 데이터는 ‘제공처’의 사정에 따라 지연되거나 잘못 표시될 수 있습니다.<br/>
#         네이버(주)는 그에 따른 스포츠 데이터의 정확성 및 신뢰성을 담보하지 않습니다. 궁금하신 사항은 <a class="link" href="https://help.naver.com/support/service/main.nhn?serviceNo=1001" target="_blank">고객센터</a>를 통해서 문의해주시기 바랍니다.
#     </p>
# </div>
# <!-- // 기록 가이드 -->
# <div class="quick_top">
# <a href="#top" onclick="topPage();">맨위로<span class="ico"></span></a>
# </div>
# </div>
# </div>
# <div id="footer">
# <div class="notice_foot">
# <strong class="title">공지</strong>
# <div class="inner">
# <a href="https://m.post.naver.com/viewer/postView.nhn?volumeNo=28970789&amp;memberNo=1156373" onclick="clickcr(this, 'not.noti', '1466402863231', '', event);" target="_blank"><span>스포츠 TV중계 편성 - 8/3(월)~8/10(월)</span></a>
# <a href="http://naver.me/G6Zo7wgw" onclick="clickcr(this, 'not.noti', '1585816955911', '', event);" target="_blank"><span>스포츠 이용자 댓글 이력 공개 안내</span></a>
# </div>
# </div>
# <ul>
# <li class="first"><a href="https://www.naver.com/rules/service.html" onclick="clickcr(this, 'fot.service', '', '', event);" target="_blank">네이버 이용약관</a></li>
# <li><a href="https://news.naver.com/main/principle.nhn" onclick="clickcr(this, 'fot.principle', '', '', event);" target="_blank">댓글/게시글 운영원칙</a></li>
# <li><a href="https://www.naver.com/rules/privacy.html" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank"><strong>개인정보처리방침</strong></a></li>
# <li><a href="https://www.naver.com/rules/disclaimer.html" onclick="clickcr(this, 'fot.disclaimer', '', '', event);" target="_blank">책임의 한계와 법적고지</a></li>
# <li><a href="#" onclick="OPS.viewOPS('ops', {url : 'https://help.naver.com/support/alias/contents2/sports/sports_2.naver'}); clickcr(this, 'fot.shelp', '', '', event); return false;" target="_blank">스포츠 고객센터</a></li>
# </ul>
# <p class="copyr">본 콘텐츠의 저작권은 네이버 및 제공처에 있으며, 이를 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address>
# <a class="logo" href="http://www.navercorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank"><img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/common/footer/ci_naver.gif" width="63"/></a>
# <em>Copyright ©</em>
# <a href="http://www.navercorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# </div>
# <script charset="UTF-8" src="https://ssl.pstatic.net/static.sports/resources/pc/2020/07/31/174012/js/src/changeUrl.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var container_link = "container";
# 	if(document.getElementById("container_link")) {
# 		document.getElementById("container_link").innerHTML = "<a href='#container' onclick=\"document.getElementById('container').tabIndex=-1;document.getElementById('container').focus();\"><span>본문으로 바로가기</span></a>";
# 	}
#
# 	function goToMobileUrl(mobileRedirectUrl) {
# 		if(mobileRedirectUrl) {
# 			location.href = "/mobileview.nhn?url=" + encodeURIComponent(mobileRedirectUrl);
# 		}else{
# 			location.href = "/index.nhn";
# 		}
# 	}
# 	lazyloadjs("https://ssl.pstatic.net/static/common/js/cs_ops_webncc.js");
# </script>
# </div>
# </body>
# </html>
