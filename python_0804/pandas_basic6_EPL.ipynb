# %%
import pandas  as pd
import numpy as np

# %%
epl= pd.read_csv("eplchart_csv.csv",encoding='utf-8')

# %%
epl.head(4)
# Out:
#    순위              팀  경기수  승점   승   무   패   득점  실점  득실차
# 0   1         리버풀 FC   38  99  32   3   3   85  33   52
# 1   2     맨체스터 시티 FC   38  81  26   3   9  102  35   67
# 2   3  맨체스터 유나이티드 FC   38  66  18  12   8   66  36   30
# 3   4          첼시 FC   38  66  20   6  12   69  54   15

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import platform

if platform.system() =='Windows':
    font_path = 'C:/Windows/Fonts/gulim.ttc' #윈도우 굴림폰트
elif platform.system() == 'Linux':    #우분투 18.04 테스트됨, 나눔폰트 설치 후
    font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# %%
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = font_name
plt.rcParams['font.size'] = 12

# %%
goal = epl.득점.tolist() #array형태로 바꿔줌

# %%
name = epl.팀.tolist()

# %%
plt.figure(figsize=(16,4))
plt.plot(name, goal)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.bar(name, goal)
plt.xticks(rotation=45)
plt.show()

# %%
lose = epl.패.tolist()

# %%
plt.figure(figsize=(8,9))
plt.pie(lose,labels=name,autopct='%1.2f',shadow=False,startangle=270)
plt.show()
