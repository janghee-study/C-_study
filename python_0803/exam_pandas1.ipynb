# %%
import pandas as pd
import numpy as np

# %%
baseball = pd.read_csv('2019_baseball_hitter20.csv',
                      encoding='utf-8')
#baseball

# %%
baseball = pd.read_excel('baseball.xlsx',encoding='utf-8')
#baseball

# %%
type(baseball)
# Out:
# pandas.core.frame.DataFrame

# %%
baseball.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
baseball.columns
# Out:
# Index(['순번', '이름', '팀명', '타율', '경기수', '타수', '안타', '2루타', '3루타', '홈런', '타점',
#        '득점', '도루', '볼넷', '삼진', '출루율', '장타율'],
#       dtype='object')

# %%
baseball.head()
# Out:
#    순번     이름  팀명     타율  경기수   타수   안타  2루타  3루타  홈런  타점  득점  도루  볼넷  삼진  \
# 0   1    양의지  NC  0.354  118  390  138   26    0  20  68  61   4  48  43
# 1   2  페르난데스  두산  0.344  144  572  197   34    0  15  88  87   1  61  54
# 2   3    박민우  NC  0.344  125  468  161   23    8   1  45  89  18  41  40
# 3   4    이정후  키움  0.336  140  574  193   31   10   6  68  91  13  45  40
# 4   5    강백호  KT  0.336  116  438  147   29    1  13  65  72   9  61  87
#
#      출루율    장타율
# 0  0.438  0.574
# 1  0.409  0.483
# 2  0.403  0.434
# 3  0.386  0.456
# 4  0.416  0.495

# %%
baseball.tail(8)
# Out:
#     순번    이름   팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 12  13   김태균   한화  0.305  127  433  132   21    0   6   62   47   3  54   94
# 13  14    샌즈   키움  0.305  139  525  160   39    1  28  113  100   1  77  101
# 14  15   김현수   LG  0.304  140  526  160   37    0  11   82   75   3  54   52
# 15  16   전준우   롯데  0.301  141  545  164   30    1  22   83   85   8  46   71
# 16  17   서건창   키움  0.300  113  426  128   23    3   2   41   67  17  49   50
# 17  18   최형우  KIA  0.300  136  456  137   31    1  17   86   65   0  85   77
# 18  19   김헌곤   삼성  0.297  114  411  122   20    1   5   46   57  10  37   41
# 19  20   손아섭   롯데  0.295  134  512  151   22    1  10   63   78  13  52   92
#
#       출루율    장타율
# 12  0.382  0.395
# 13  0.396  0.543
# 14  0.370  0.437
# 15  0.359  0.481
# 16  0.373  0.383
# 17  0.413  0.485
# 18  0.361  0.387
# 19  0.360  0.400

# %%
#홈런수를 기준으로 테이블을 정렬해주세요!!
baseball.sort_values(by='홈런',ascending=False)
# Out:
#     순번     이름   팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 13  14     샌즈   키움  0.305  139  525  160   39    1  28  113  100   1  77  101
# 6    7    로하스   KT  0.322  142  521  168   30    3  24  104   68   4  49  120
# 15  16    전준우   롯데  0.301  141  545  164   30    1  22   83   85   8  46   71
# 0    1    양의지   NC  0.354  118  390  138   26    0  20   68   61   4  48   43
# 11  12    김하성   키움  0.307  139  540  166   38    2  19  104  112  33  70   80
# 17  18    최형우  KIA  0.300  136  456  137   31    1  17   86   65   0  85   77
# 1    2  페르난데스   두산  0.344  144  572  197   34    0  15   88   87   1  61   54
# 8    9    유한준   KT  0.317  139  501  159   19    1  14   86   61   3  52   61
# 4    5    강백호   KT  0.336  116  438  147   29    1  13   65   72   9  61   87
# 9   10    채은성   LG  0.315  128  470  148   18    1  12   72   59   2  24   67
# 14  15    김현수   LG  0.304  140  526  160   37    0  11   82   75   3  54   52
# ...

# %%
#del baseball['순번']
baseball
# Out:
#        이름   팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 0     양의지   NC  0.354  118  390  138   26    0  20   68   61   4  48   43
# 1   페르난데스   두산  0.344  144  572  197   34    0  15   88   87   1  61   54
# 2     박민우   NC  0.344  125  468  161   23    8   1   45   89  18  41   40
# 3     이정후   키움  0.336  140  574  193   31   10   6   68   91  13  45   40
# 4     강백호   KT  0.336  116  438  147   29    1  13   65   72   9  61   87
# 5     고종욱   SK  0.323  137  492  159   25    7   3   56   76  31  18   89
# 6     로하스   KT  0.322  142  521  168   30    3  24  104   68   4  49  120
# 7     박건우   두산  0.319  127  458  146   27    5  10   64   83  12  60   57
# 8     유한준   KT  0.317  139  501  159   19    1  14   86   61   3  52   61
# 9     채은성   LG  0.315  128  470  148   18    1  12   72   59   2  24   67
# 10    이천웅   LG  0.308  138  546  168   24    3   2   48   88  21  57   82
# 11    김하성   키움  0.307  139  540  166   38    2  19  104  112  33  70   80
# ...

# %%
baseball
data = baseball
data #복사도 가능하다
# Out:
#        이름   팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 0     양의지   NC  0.354  118  390  138   26    0  20   68   61   4  48   43
# 1   페르난데스   두산  0.344  144  572  197   34    0  15   88   87   1  61   54
# 2     박민우   NC  0.344  125  468  161   23    8   1   45   89  18  41   40
# 3     이정후   키움  0.336  140  574  193   31   10   6   68   91  13  45   40
# 4     강백호   KT  0.336  116  438  147   29    1  13   65   72   9  61   87
# 5     고종욱   SK  0.323  137  492  159   25    7   3   56   76  31  18   89
# 6     로하스   KT  0.322  142  521  168   30    3  24  104   68   4  49  120
# 7     박건우   두산  0.319  127  458  146   27    5  10   64   83  12  60   57
# 8     유한준   KT  0.317  139  501  159   19    1  14   86   61   3  52   61
# 9     채은성   LG  0.315  128  470  148   18    1  12   72   59   2  24   67
# 10    이천웅   LG  0.308  138  546  168   24    3   2   48   88  21  57   82
# 11    김하성   키움  0.307  139  540  166   38    2  19  104  112  33  70   80
# ...

# %%
#이름,홈런만 추출하라
baseball.loc[:,['이름','홈런']].head(3)
# Out:
#       이름  홈런
# 0    양의지  20
# 1  페르난데스  15
# 2    박민우   1

# %%
#loc를 이용해서 이름 홈런 경기수 타율 삼진을 출력하자
#인덱값으로 3~7까지만 출력
baseball.loc[3:7,['이름','경기수','타율','삼진']]
# Out:
#      이름  경기수     타율   삼진
# 3   이정후  140  0.336   40
# 4   강백호  116  0.336   87
# 5   고종욱  137  0.323   89
# 6   로하스  142  0.322  120
# 7   박건우  127  0.319   57
